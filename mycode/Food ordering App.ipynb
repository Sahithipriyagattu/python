# %% [markdown]
# # Food Ordering app

# %% [markdown]
# ### 1)Authentication
# Ask the user whether he is admin or user?
# -  if User is admin Redirect into Admin panel
# -  if user is user then Redirect to user panel
#
# ### 2)Admin Panel
# Should be able to add Food Items with following details
# -  FoodID (Auto generated by the system)
# -  Name of the Food Item
# -  Quantity of the food item
# -  Price
# -  Discount
# -  Stock
# -  Edit food items using FoodID.
# -  View the list of all food items.
# -  Remove a food item from the menu using FoodID.
#
# ### 3) User Panel
# Should be able to do these
#  1.  If he is an existing user then redirect directly to login.
#  2.  if he is new entry then register
# <br> </br>
# Register on the application. Following to be entered for registration:
#
# -  Full Name
# -  Phone Number
# -  Email
# -  Address
# -  Password
# -  Log in to the application
# -  The user will see 3 options:
#     - Place New Order
#     - Order History
#     - Update Profile
# -  Place New Order: The user can place a new order at the restaurant.
# -  Show list of food. The list item should as follows:
#  1. Tandoori Chicken (4 pieces) [INR 240]
#  2. Vegan Burger (1 Piece) [INR 320]
#  3. Truffle Cake (500gm) [INR 900]
# -  Users should be able to select food by entering an array of numbers. For example, if the user wants to order Vegan Burger and Truffle Cake they should enter [2, 3]
# -  Once the items are selected user should see the list of all the items selected. The user will also get an option to place an order.
# - Order History should show a list of all the previous orders
# - Update Profile: the user should be able to update their profile.

# %% [markdown]
# # 1) Authentication

# %%
class food_app:
    def __init__(self):
        self.user_details={}
        self.admin_details={}
        #self.users_login=[]
        #self.admin_login=[]
        self.admin_un = {'sahithi': '123456'}
        self.all_admin_user_details={'sahithi':['Sahithi',9988776655,'s@gmail.com','F' ]}
        self.un={'user01':'123456'}
        self.login=False
        self.all_user_details={'user01':['Sita Ram', '1234567890' ,'sitar@gmail.com','F','Hyderabad' ]}
        self.food_items_list =[]
        self.food_items_menu={1:['Tandoori Chicken', '(4 Pieces)', '[INR 250]' ],
                                                2:['Vegan Burger', '(1 Piece)', '[INR 320]'], 
                                                3:['Truffle Cake', '(500gm)','[INR 900]'] 
                                                 }
        self.s=0
        self.a=0
        self.food_id=0
        self.stock = "\n_______________________________\nALL ITEMS ARE IN STOCK\n_______________________________"
        self.discount = "NO DISCOUNT"
        self.user_choice_list=[]
        self.oh = 0
        self.o_fail = 0
    def prompt(self):
        print("HELLO WELCOME TO FOOD ORDERING APP!!\n")
        value_1 = input("Are you an Admin or an User? \n Type in A for Admin and U if you are an user\t:")
        value_1 = value_1.lower()
        answer = value_1
        if value_1 == 'a':
            self.admin_Auth()
        elif value_1== 'u':
            self.user_Auth()
        else:
            print('Invalid Choice!! please enter A if you an Admin or Enter U if you are an User' )
            self.prompt()
        
    def admin_Auth(self):
        self.a = input("please enter your Username:\t")
        if self.a in self.admin_un:
            pas1 = input("please Enter your Password:\t")
            if pas1 == self.admin_un[self.a]:
                self.login=True
                print("Logged in Sucessfully")
                self.admin_portal( )
            else:
                print("You Have entered wrong password try again!!")
        else:
            print("Check the username its not found! Please Contact Admin Team!")
            
    def admin_portal(self):
        if self.login==True:
            self.admin_portal_fi()
            print('\n',end=' ')
            print('\n',end=' ')
            print('\n',end=' ')
            print(f"Hello {self.a} Please choose from the options below \n 1. Add a food item! \n 2. Remove a food item! \n 3. Update Food items ")
            choice1 = input("Please Enter Your choice of the number here:\t")
            if choice1 == '1':
                self.Add_fi()
            elif choice1 == '2':
                self.remove_fi()
            elif choice1 == '3':
                self.update_fi()
            else:
                print(f"The choice {choice} you have entered is not correct!! Please Enter a valid choice")
                self.admin_portal()
        else:
            print("Please Login to continue.....")
            self.admin_Auth()

    def user_Auth(self):
        Auth = input("If you are an existing user please Type ' L ' to Login \n If you are a new user please select ' R' register")
        Auth = Auth.lower()
        if Auth == 'r': 
            self.username=input("Please Enter your Username")
            if len(self.username) >= 6:
                if self.username not in self.un:
                    print("******  Hello Welcome New User __/ \__ Please Register yourself ********")
                    self.name = input ("Enter Your Full Name\t")
                    self.phonenumber = input("Please Enter Your Phonenumber")
                    self.email = input ("Please Enter your Email \t")
                    self.gender = input("Please Enter Your Gender\t")
                    self.password = input("Please type to Create your password:\t ")
                    a = self.username
                    self.un[self.username] = self.password
                    self.all_user_details[a] = [self.name,self.phonenumber, self.email , self.gender]
                    self.user_login()
                else:
                    print("This Username has already been taken....Try with another... or if you are an existing user please Login")
                    self.user_login()
            else:
                print("The username must be atleast 6 digits try mixing alphabets and numbers to produce an Unique Username")
                self.user_login()
        elif Auth == 'l':
            self.user_login()
        else:
            print(f"The choice {Auth} is Invalid!!! please select either ' L ' to login or 'R' to Register")
            self.user_Auth()

    def user_login(self):
        self.s = input("please enter your Username:\t")
        if self.s in self.un:
            pas = input("please Enter your Password:\t")
            if pas == self.un[self.s]:
                self.login=True
                print("Logged in Sucessfully")
                self.user_portal()
            else:
                print("You Have entered wrong password try again!!")
        else:
            print("Check the username its not found! New user? Try register!")
    
    def user_portal(self):
        if self.login==True:
            self.profile()
            print(f" Hello {self.s} Please choose from the options below \n 1. Place a New Order \n 2. Order History \n 3. Update Profile ")
            choice = int(input("Please Enter Your choice of the number here:\t"))
            if choice == 1:
                self.new_order()
            elif choice == 2:
                self.order_history_empty()
            elif choice == 3:
                self.update_profile()
            else:
                print(f"The choice {choice} you have entered is not correct!! Please Enter a valid choice")
        else:
            print("Please Login to continue.....")
            
        

    def new_order(self):
        self.food_items()
        #ser_choice_list = []
        print("\n")
        user_choice = input("Type the food_ID of the items seperated by a comma(,)to order \n If you want to Exit to the main menu press ' 0 ' ")
        print('\n',end =' ')
        if user_choice == '0':
            self.user_portal()
        user_choice = user_choice.split(',')
        self.user_choice_list = user_choice
        print("Selected Food Items are:", end = ' ')
        for key in self.user_choice_list:
            key = int(key)
            print('\n')
            print(f"{key}" + '.' , end = ' ')
            for j in self.food_items_menu[key]:
                print(j, end = ' ')       
        self.confirm()
            

                
                
        
    def confirm(self):
        order = input("To Order please press 'O' \nTo Edit your Choices please press 'E' \nTo Cancel the order please press 'C'\n")
        order=order.lower()
        if order == 'o':
            confirmation = input("Proceed to Order Y or N?")
            if confirmation == 'Y' or confirmation == 'y':
                stock = 1 
                self.oh == 1
                print("__________________________________________________________________________")
                print("Your Order Has Been Placed Successfully")
                print("__________________________________________________________________________")
                oh=input("please check your order at order history - press Y to continue.... or press N to go to main Menu")
                oh = oh.lower()
                if oh == 'y':
                    self.oh == 1
                    self.order_history_o()
                else:
                    self.oh == 1
                    self.user_portal()
            elif confirmation == 'N' or confirmation == 'N':
                self.oh = 2
                self.order_history_failed()
            else:
                self.new_order()
        elif order == 'e' or order == 'c':
            self.new_order()
        else:
            print("please select appropriate option")
            self.confirm()
                
     
        
    def order_history_o(self):
        print("---------------------YOUR ORDER HISTORY--------------------")
        for key in self.user_choice_list:
            key = int(key)
            print('\n')
            print(f"{key}" + '.' , end = ' ')
            for j in self.food_items_menu[key]:
                print(j, end = ' ') 
            print("Order for These Items has been successful! ")
    def order_history_failed(self):
        print("---------------------YOUR ORDER HISTORY--------------------")
        for key in self.user_choice_list:
            key = int(key)
            print('\n')
            print(f"{key}" + '.' , end = ' ')
            for j in self.food_items_menu[key]:
                print(j, end = ' ') 
        print("Order for These Items has been unsuccessful! ")
        cancelled = input("Your Order has been cancelled press M to go to the Order Menu else Press Q to Quit")
        cancelled = cancelled.lower()
        if cancelled == 'm':
            self.new_order()
    def order_history_empty(self):
        print("---------------------YOUR ORDER HISTORY--------------------")
        if self.oh == 0:
            print("You Did not order Anything Yet Today!")
        else:
            self.order_history_o()
    
    def update_profile(self):
        self.profile()
        d = input("\n Please Enter the username")
        a = int(input("\n Enter \n 1 - To change your Name \n 2 - To change Your phonenumber \n 3 - To change your email \n 4 - To change your gender \n 5 - To change your address \n 6 - To change your password \n 7 - To change your username"))
        if a == 1:
            b = self.all_user_details[d][0]
            c = input(" \n Enter new name ")
            self.all_user_details[c] = b
            print ("The name has been changed successfully!")
            self.user_portal()
        elif a == 2:
            b = self.all_user_details[d][1]
            c = input(" \n Enter new phonenumber ")
            self.all_user_details[c] = b
            print ("ThePhone number has been changed successfully!")
            self.user_portal()
        elif a == 3:
            b = self.all_user_details[d][2]
            c = input(" \n Enter your new mail ")
            self.all_user_details[c] = b
            print ("The price of the item has been changed successfully!")
            self.user_portal()
        elif a == 4:
            b = self.all_user_details[d][3]
            c = input(" \n Enter your gender")
            self.all_user_details[c] = b
            print ("The gender has been changed successfully!")
            self.user_portal()
        elif a == 5:
            b = self.all_user_details[d][4]
            c = input(" \n Enter your new Address")
            self.all_user_details[c] = b
            print ("The Address has been changed successfully!")
            self.user_portal()
        elif a == 6:
            b = self.un[d]
            c = input(" \n Enter your new password")
            self.un = b
            print ("The password has been changed successfully!")
            self.user_portal()
        elif a == 7:
            c = input(" \n Enter your new username")
            self.un[c] = self.un[d]
            print ("The username has been changed successfully!")
            self.user_portal()
        else:
            print("Invalid Choice!!")
            self.user_portal()
    
    def food_items(self):
        #Food_id = 3
       # print('| FOOD ID |' + '\t'*2 + '| FOOD ITEM|' + '\t'*2 + '| QUANTITY |' + '\t'*2 + '| PRICE |' , end = '    ')
        for i in self.food_items_menu:
            print('\n')
            print( ' ' + '\t' + f'{i}' + '.',end='')
            print(end = '                     ')
            for j in self.food_items_menu[i]:   
                print(j,  end = '  ' )
               # print(end ='                ')
            
    def admin_portal_fi(self):
        print(self.stock)
        print(self.discount)
        print('_______________________________________________________________________________________________________________________________________________________________')
        print('                                                                MENU                                                                                   ')
        print('_______________________________________________________________________________________________________________________________________________________________')
        #print('| FOOD ID |' + '\t'*2 + '| FOOD ITEM|' + '\t'*2 + '| QUANTITY |' + '\t'*2 + '| PRICE |'  , end = '    ')

        for i in self.food_items_menu:
            print('\n')
            print( ' ' + '\t' + f'{i}' + '.',end='')
            print(end = '                     ')
            for j in self.food_items_menu[i]:   
                print(j,  end = '  ' )
                print(end ='                ')

    def Add_fi(self):
        food_id = len(self.food_items_menu.keys())
        current_f_id = int(food_id)
        current_f_id = current_f_id + 1
        print(f"Please Enter the following details to make a new item Entry for Food_ID:\t {current_f_id}")
        item_name = input("\n Please Enter the Food_ name\t")
        self.food_items_list.append(item_name)
        quantity = input('\n Enter the quantity of the Food Item\t')
        item_quantity = '(' + f'{quantity}'+')'
        self.food_items_list.append(item_quantity)
        price = int(input(" \n Please Enter the price\t "))
        item_price = '[INR'+ f'{price} ' +']'
        discount = (input("Any Discount? Y or N")).lower()
        self.food_items_list.append(item_price)
        self.food_items_menu[current_f_id] = self.food_items_list
        self.admin_portal()
#         print(end = ' ')
#         more = input("\n\n Do You wish to Add more...Y or N??")
#         more =more.lower()
#         if more == 'y':
#             print('\n', end = ' ')
#             self.Add_fi()
#         elif more == 'n':
#             self.admin_portal()
#         else:
#             print("please Select a Valid Option!!")
#             self.Add_fi()
#             #print(current_f_id)
                
    def remove_fi(self):
        self.food_items()
        f__id=int(input(" \n Please Enter the Food ID of the Food Item that u want to be removed or Deleted from the Menu!!\t)"))
        print(f"The Item with {f__id} is {self.food_items_menu[f__id]}")
        print('\n')
        conform = input("Do You Wish to Continue......Y or N?? \t")
        conform = conform.upper()
        if conform == 'Y':
            removed_item = self.food_items_menu.pop(f__id)
            self.food_items()
            print('\n')
            print(f"The Item number {f__id} {removed_item} Has been Removed / Deleted from the Food Menu Successfully")
            self.remove_fi()
        elif conform == 'N':
            self.admin_portal()
        else:
            self.admin_portal()
            print("please select a valid option!!")
    
    def profile(self):
        print ("============Your Profile=================")
        print("Username :\t" + self.s)
        print('\n', end =' ')
        print("Name :\t"+ self.all_user_details[self.s][0])
        print('\n', end =' ')
        print("Phone Number:\t" + self.all_user_details[self.s][1])
        print('\n', end =' ')
        print("Email :\t"+ self.all_user_details[self.s][2])
        print('\n', end =' ')
        print("Gender :\t"+ self.all_user_details[self.s][3])
        print('\n', end =' ')
        print("Address :\t"+ self.all_user_details[self.s][4])
        print('\n', end =' ')
            
    def update_fi(self):
        self.food_items()
        a = int(input("\n Enter \n 1 - To change the name of the item \n 2 - To change the Quantity of the item \n 3 - To change the Price of the item \n 4 - To change the stock of the item \n 5 - To update the discount on the item"))
        d = int(input("\n Please Enter the food_id"))
        if a == 1:
            b = self.food_items_menu[d][0]
            c = input(" \n Enter new name for the food item")
            self.food_items_menu[c] = b
            print ("The name of the item has been changed successfully!")
            self.admin_portal()
        elif a == 2:
            b = self.food_items_menu[d][1]
            c = input(" \n Enter new quantity for the food item")
            self.food_items_menu[c] = b
            self.admin_portal()
            print ("The quantity of the item has been changed successfully!")
        elif a == 3:
            b = self.food_items_menu[d][2]
            self.admin_portal()
            c = input(" \n Enter new price for the food item")
            self.food_items_menu[c] = b
            print ("The price of the item has been changed successfully!")
        elif a == 4:
            b = input(" \n Update the stock for the food item (IN STOCK or OUT OF STOCK)")
            self.stock = "\n_____________________________"+'\nALL ITEMS '+ b +"\n_____________________________"
            print ("The stock has been updated successfully!")
            self.admin_portal()
        elif a == 5:
            b = input(" \n Enter new discount for the food item (ex: NO DISCOUNT or 5% DIS etc..)")
            self.discount = b
            print ("The discount status been changed successfully!")
            self.admin_portal()
        else:
            print("Invalid Choice!!")
            self.admin_portal()
        
fa = food_app()
fa.prompt()
# Out:
# HELLO WELCOME TO FOOD ORDERING APP!!
#
# Are you an Admin or an User?
#  Type in A for Admin and U if you are an user	:u
# If you are an existing user please Type ' L ' to Login
#  If you are a new user please select ' R' registerl
# please enter your Username:	user01
# please Enter your Password:	123456
# Logged in Sucessfully
# ============Your Profile=================
# Username :	user01
#
#  Name :	Sita Ram
#
#  Phone Number:	1234567890
#
#  Email :	sitar@gmail.com
#
#  Gender :	F
#
#  Address :	Hyderabad
#
#   Hello user01 Please choose from the options below
#  1. Place a New Order
#  2. Order History
#  3. Update Profile
# Please Enter Your choice of the number here:	3
# ============Your Profile=================
# Username :	user01
#
#  Name :	Sita Ram
#
#  Phone Number:	1234567890
#
#  Email :	sitar@gmail.com
#
#  Gender :	F
#
#  Address :	Hyderabad
#
#
#  Please Enter the usernameuser01
#
#  Enter
#  1 - To change your Name
#  2 - To change Your phonenumber
# ...
